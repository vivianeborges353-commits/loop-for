# %% [markdown]
# <a href="https://colab.research.google.com/github/vivianeborges353-commits/loop-for/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for i in range(10):
  print("teste", i)
# Out:
# teste 0
# teste 1
# teste 2
# teste 3
# teste 4
# teste 5
# teste 6
# teste 7
# teste 8
# teste 9

# %%
frutas = ["maca","banana","laranja"]
for item in frutas:
  print(item)
# Out:
# maca
# banana
# laranja

# %%
lista_vendas = [1000,500,800,1500,2000,2300]
for i in lista_vendas:
  print(i)
# Out:
# 1000
# 500
# 800
# 1500
# 2000
# 2300

# %%
lista_vendas = [1000,500,800,1500,2000,2300]
meta = 1200
percentual_bonus = 0.1
for venda in lista_vendas:
  if venda  >= meta:
    bonus = percentual_bonus * venda
  else:
    bonus = 0
  print(bonus)
# Out:
# 0
# 0
# 0
# 150.0
# 200.0
# 230.0

# %%
vendas_diarias = [20,30,40,50]
meta = 30
dias_acima_da_meta = 0
for venda in vendas_diarias:
  if venda > meta:
    #dias_acima_da_meta = dias_acima_da_meta +1
      dias_acima_da_meta += 1         #atribuição
print(dias_acima_da_meta)
# Out:
# 2

# %%
#Atividade 01
vendas_funcionarios = [2800,1500,400,1000,3500]
meta = 3000
bonus = 0.05
for venda in vendas_funcionarios:
  if venda > meta:
    resultado =venda *bonus
  else:
     resultado=0
  print(resultado)
# Out:
# 0
# 0
# 0
# 0
# 175.0

# %%
vendas_diarias = [2000,3000,4000,1800,5000,2700]
meta = 2500
dias= 0
for venda in vendas_diarias:
  if venda > meta:
      dias=dias+1
print(dias)
# Out:
# 4

# %%
vendas_vendedores = [1500,2500,1800,3200,4000,2800]
meta = 2500
comissao=0.8
for venda in vendas_vendedores:
  if venda > meta:
      dias=dias+1
print(dias)
# Out:
# 79
