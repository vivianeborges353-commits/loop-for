# %% [markdown]
# <a href="https://colab.research.google.com/github/vivianeborges353-commits/loop-for/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
lista_vendas = [1000,500,800,1500,2000,2300]
meta = 1200
percentual_bonus = 0.1
for venda in lista_vendas:
  if venda  >= meta:
    bonus = percentual_bonus * venda
  else:
    bonus = 0
  print(bonus)
# Out:
# 0
# 0
# 0
# 150.0
# 200.0
# 230.0

# %%
lista_vendas = [1000,500,800,1500,2000,2300]
meta = 1200
percentual_extra = 0.1
bonus_extra = 50
for venda in lista_vendas:
  bonus = 0
  if venda  >= meta:
    bonus =venda * percentual_extra
  if venda >=2000:
    bonus = bonus + bonus_extra
  print(f"venda:{venda}->bonus: R${bonus}")
# Out:
# venda:1000->bonus: R$0
# venda:500->bonus: R$0
# venda:800->bonus: R$0
# venda:1500->bonus: R$150.0
# venda:2000->bonus: R$250.0
# venda:2300->bonus: R$280.0

# %%
lista_vendas = [1000, 500, 800, 1500, 2000, 2300]

maior_vendas = lista_vendas[0]

for venda in lista_vendas:
  if venda > maior_vendas:
    maior_vendas = venda #2300
print("A maior venda", maior_vendas)
# Out:
# A maior venda 2300
